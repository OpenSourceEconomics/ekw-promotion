# %%
import respy as rp
import pandas as pd

pd.options.display.max_rows = 999
# %load_ext nb_black

# %%
model = "kw_97_basic"
_, options, _ = rp.get_example_model(model)
params = pd.read_pickle("params_revised_basic.pkl")

# %%
df_options = pd.DataFrame.from_dict(options, orient="index", columns=["value"])

# %%
df_options
# Out:
#                                                                   value
# estimation_draws                                                    200
# estimation_seed                                                     500
# estimation_tau                                                      500
# interpolation_points                                                 -1
# n_periods                                                            50
# simulation_agents                                                  5000
# simulation_seed                                                     132
# solution_draws                                                      500
# solution_seed                                                       456
# monte_carlo_sequence                                             random
# covariates            {'hs_graduate': 'exp_school >= 12', 'co_gradua...

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
params
# Out:
#                                                               value  \
# category                name
# delta                   delta                          7.881765e-01
# wage_white_collar       constant                       8.323817e+00
#                         exp_school                     9.859541e-02
#                         exp_white_collar               1.219786e-01
#                         exp_white_collar_square       -1.438115e-01
#                         exp_blue_collar                9.994745e-02
#                         exp_military                   7.055843e-03
#                         type_1                        -6.715314e-02
#                         type_2                        -4.248796e-01
#                         type_3                        -4.997401e-01
# wage_blue_collar        constant                       8.909449e+00
#                         exp_school                     1.598533e-02
# ...
